# %% [markdown]
# # Análisis, Exploración y Preparación de datos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importación de datos

# %%
df = pd.read_csv("ejercicio3.csv", header=0,names=['Year','IdAsignatura','porcentaje_invictos_asig'])
df.head()
# Out:
#    Year  IdAsignatura  porcentaje_invictos_asig
# 0  2000             6                    0.6115
# 1  2000             2                    0.6115
# 2  2000             1                    0.6115
# 3  2000             4                    0.6115
# 4  2000             3                    0.6115

# %% [markdown]
# # Características de los atributos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1486 entries, 0 to 1485
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      1486 non-null   int64
#  1   IdAsignatura              1486 non-null   int64
#  2   porcentaje_invictos_asig  1486 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 35.0 KB

# %%
df.columns
# Out:
# Index(['Year', 'IdAsignatura', 'porcentaje_invictos_asig'], dtype='object')

# %% [markdown]
# # Secuencia Correspondencia de valores numéricos a categóricos

# %%
# analizar semestre
df.Year.astype("category")
# Out:
# 0       2000
# 1       2000
# 2       2000
# 3       2000
# 4       2000
#         ...
# 1481    2020
# 1482    2020
# 1483    2020
# 1484    2020
# 1485    2020
# Name: Year, Length: 1486, dtype: category
# Categories (21, int64): [2000, 2001, 2002, 2003, ..., 2017, 2018, 2019, 2020]

# %%
df.IdAsignatura.astype("category")
# Out:
# 0        6
# 1        2
# 2        1
# 3        4
# 4        3
#         ..
# 1481     9
# 1482    16
# 1483    10
# 1484    20
# 1485     7
# Name: IdAsignatura, Length: 1486, dtype: category
# Categories (31, int64): [1, 2, 3, 4, ..., 31, 32, 33, 34]

# %% [markdown]
# # Función que convierte valores categóricos a numéricos

# %%
def Categ_Numerico(datos):
    # Conversión de un tipo de datos al tipo categorico
    datos = datos.astype("category")
    # Obtención del código de la categoría
    return datos.astype("category").cat.codes

# %%
df['Year'] = Categ_Numerico(df['Year'])
df['IdAsignatura'] = Categ_Numerico(df['IdAsignatura'])
df.head()
# Out:
#    Year  IdAsignatura  porcentaje_invictos_asig
# 0     0             5                    0.6115
# 1     0             1                    0.6115
# 2     0             0                    0.6115
# 3     0             3                    0.6115
# 4     0             2                    0.6115

# %% [markdown]
# # Grabación de conversión de datos

# %%
df.to_csv("asistencia_doc.csv", sep=',',header=True, index=False)

# %% [markdown]
# # Histograma

# %% [markdown]
# *   El histograma 1 muestra el nro de invictos vs Year
# *   El histograma 2 muestra el nro de invictos vs IdAsignatura
# *   El histograma 3 muestra el nro de invictos vs porcentaje_invictos_por_asig

# %%
df.hist(figsize=(12, 9))
plt.show()

# %% [markdown]
# Year = [2000, 2001, 2002, 2003, ..., 2017, 2018, 2019, 2020]
#
# Codigo_asig = [1, 2, 3, 4, ..., 31, 32, 33, 34]
#
# + 0001	Algorítmica I,
# + 0002	Ofimatica,
# + 0003	Matemática I,
# + 0004	Herramientas de Desarrollo I,
# + 0005	Arquitectura del Computador,
# + 0006	Contabilidad I,
# + 0007	Algorítmica II,
# + 0008	Diseño Gráfico,
# + 0009	Matemática II,
# + 0010	Herramientas de Desarrollo II
# + 0011	Software Contable
# + 0012	Contabilidad II
# + 0013	Redes y Conectividad
# + 0014	Análisis y Diseño de Sist. de Inf. I
# + 0015	Matemática III
# + 0016	Base de Datos I
# + 0017	Herramientas de Desarrollo III
# + 0018	Diseño de Páginas Web
# + 0019	Base de Datos II
# + 0020	Herramientas de Desarrollo IV
# + 0021	Análisis y Diseño de Sist. de Inf. II
# + 0022	Administración y Liderazgo
# + 0023	Desarrollo de Software
# + 0024	Comercio Electronico
# + 0025	Sistemas Distribuidos
# + 0026	Formulacion y Evaluacion de Proyectos
# + 0027	Administración de Centros de Computo
# + 0031	Analisis y Diseño de Sistemas
# + 0032	Diseño y Gestion de Base de Datos
# + 0033	Herramientas de Desarrollo de Software
# + 0034	Redes y Teleprocesos

# %% [markdown]
# INTERPRETACION:
#  - en el primer histograma  se observa que en el año 2020 hubo mayor cantidad de alumnos aprobados
#  - En el segundo histograma se observa que el curso de algoritmica 1 tiene gran numero de aprobados
#  - Los ultimos cursos como herramientas de desarrollo de software y redes tiene muy pocos aprobados, esto es debido aque muy pocos alumnos llegan hasta dicho mudulo y la complejidad del curso
#  - En el histograma 3 se observa que el porcentaje de invictos que se presenta con mayor frecuencia se encuentra en el rango de 60% y 70%

# %% [markdown]
# # Distribución

# %%
df.groupby('Year').mean() # porcentaje promedio de invictos por año
# Out:
#       IdAsignatura  porcentaje_invictos_asig
# Year
# 0         2.200000                  0.611500
# 1         6.965517                  0.592972
# 2        11.877551                  0.712653
# 3        13.000000                  0.679833
# 4        13.000000                  0.708562
# 5        11.375000                  0.654967
# 6        14.068966                  0.704259
# 7        12.600000                  0.658850
# 8        13.000000                  0.693691
# 9        15.000000                  0.686422
# 10       14.393258                  0.660198
# 11       14.393258                  0.683021
# 12       15.000000                  0.702304
# 13       14.393258                  0.693169
# 14       14.068966                  0.683881
# 15       14.393258                  0.636655
# 16       14.393258                  0.631054
# 17       15.000000                  0.647653
# 18       14.393258                  0.674183
# 19       14.393258                  0.713738
# ...

# %%
df.groupby('IdAsignatura').mean() # porcentaje promedio de invictos por asignatura
# Out:
#                    Year  porcentaje_invictos_asig
# IdAsignatura
# 0             10.444444                  0.556004
# 1             10.444444                  0.556004
# 2             10.444444                  0.556004
# 3             10.444444                  0.556004
# 4             10.641509                  0.554957
# 5             10.444444                  0.556004
# 6             10.537037                  0.621585
# 7             10.537037                  0.621585
# 8             10.537037                  0.621585
# 9             10.537037                  0.621585
# 10            10.537037                  0.621585
# 11            10.537037                  0.621585
# 12            11.020000                  0.687998
# 13            11.020000                  0.687998
# 14            11.020000                  0.687998
# 15            11.020000                  0.687998
# 16            11.020000                  0.687998
# ...

# %% [markdown]
# #Estadisticos descriptivos

# %%
df.describe()
# Out:
#               Year  IdAsignatura  porcentaje_invictos_asig
# count  1486.000000   1486.000000               1486.000000
# mean     11.051817     13.754374                  0.675516
# std       5.283798      8.525713                  0.129117
# min       0.000000      0.000000                  0.346200
# 25%       7.000000      6.000000                  0.593600
# 50%      11.000000     13.000000                  0.657750
# 75%      16.000000     21.000000                  0.748750
# max      20.000000     30.000000                  1.000000

# %% [markdown]
# #Diagrama de caja

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import seaborn as sns
plt.figure(figsize = [15, 5]) 
sns.boxplot(data = df);

# %% [markdown]
# # Correlación lineal
# Gráficos Cuantil-Cuantil (Q-Q plots)
#
# Un gráfico Cuantil-Cuantil permite observar cuan cerca está la
# distribución de un conjunto de datos a alguna distribución ideal
# ó comparar la distribución de dos conjuntos de datos.
#
# Si la linea es trazada como diagonal, existe alta approximación de los datos a la distribución ideal.
#
# **¿Por qué es importante conocer las distribuciones?**
#
# Las distribuciones de probabilidad teóricas son útiles en la inferencia estadística porque sus propiedades y características son conocidas. Si la distribución real de un conjunto de datos dado es razonablemente cercana a la de una distribución de probabilidad teórica, muchos de los cálculos se pueden realizar en los datos reales utilizando hipótesis extraídas de la distribución teórica.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import statistics
import pylab
import scipy.stats as stats

stats.probplot(df['porcentaje_invictos_asig'],dist=stats.poisson(statistics.median(df['porcentaje_invictos_asig'])), plot=pylab)
pylab.show()

# %%
import statistics
import pylab
import scipy.stats as stats

stats.probplot(df['porcentaje_invictos_asig'],dist=stats.expon(statistics.median(df['porcentaje_invictos_asig'])), plot=pylab)
pylab.show()

# %%
import pylab
import scipy.stats as stats

stats.probplot(df['porcentaje_invictos_asig'],dist=stats.norm, plot=pylab)
pylab.show()

# %% [markdown]
# # Correlación Pearson
#
# La correlación es una medida de la relación (covariación) lineal entre dos variables cuantitativas contínuas (x, y). La manera más sencilla de saber si dos variables están correlacionadas es determinar si co-varían (varían conjuntamente)
#
# La correlación es un tipo de asociación entre dos variables numéricas, específicamente evalúa la tendencia (creciente o decreciente) en los datos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El valor del índice de correlación varía en el intervalo [-1,1]
#
# Si este coeficiente es igual a 1 o -1 (o cercano a estos valores) significa que una variable es fruto de una transformación lineal de la otra. Teniendo una relación directa al tratarse de 1 (cuando una variable aumenta, la otra también), mientras que existirá una relación inversa al tratarse de -1 (cuando una variable aumenta la otra disminuye).
#
# Mientras que, Si r = 0 (o cercano a este valor) no existe relación lineal, aunque puede existir algún otro tipo de relación no lineal.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Matriz de correlación

# %%
df_pearson = df.corr(method='pearson')
df_pearson
# Out:
#                               Year  IdAsignatura  porcentaje_invictos_asig
# Year                      1.000000      0.112127                 -0.030552
# IdAsignatura              0.112127      1.000000                  0.722146
# porcentaje_invictos_asig -0.030552      0.722146                  1.000000

# %% [markdown]
# # Matriz de correlacion en mapa de colores

# %%
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,8))
sns.heatmap(df_pearson,ax=ax)

# %% [markdown]
# * Se observa que la asignatura es una caracteristica que influye en el porcentaje de aprobados
