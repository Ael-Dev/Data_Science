# %% [markdown]
# # Análisis, Exploración y Preparación de datos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importación de datos

# %%
df = pd.read_csv("ejercicio1.csv", header=0,names=['Semestre','Modulo','Turno','Seccion','IdDocente','Asistencia'])
df.head()
# Out:
#    Semestre    Modulo   Turno Seccion  IdDocente Asistencia
# 0  2010 - I   Mod - V  Mañana       A         26    Puntual
# 1  2010 - I   Mod - V  Mañana       A         37    Puntual
# 2  2010 - I  Mod - VI   Tarde       A         56    Puntual
# 3  2010 - I  Mod - VI   Tarde       A         56    Puntual
# 4  2010 - I  Mod - VI   Tarde       A         56    Puntual

# %% [markdown]
# # Características de los atributos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38414 entries, 0 to 38413
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Semestre    38414 non-null  object
#  1   Modulo      38414 non-null  object
#  2   Turno       38414 non-null  object
#  3   Seccion     38414 non-null  object
#  4   IdDocente   38414 non-null  int64
#  5   Asistencia  38414 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1.8+ MB

# %%
df.columns
# Out:
# Index(['Semestre', 'Modulo', 'Turno', 'Seccion', 'IdDocente', 'Asistencia'], dtype='object')

# %% [markdown]
# # Secuencia Correspondencia de valores numéricos a categóricos

# %%
# analizar semestre
df.Semestre.astype("category")
# Out:
# 0        2010 - I
# 1        2010 - I
# 2        2010 - I
# 3        2010 - I
# 4        2010 - I
#            ...
# 38409    2013 - I
# 38410    2013 - I
# 38411    2013 - I
# 38412    2013 - I
# 38413    2013 - I
# Name: Semestre, Length: 38414, dtype: category
# Categories (10, object): ['2010 - I', '2010 - II', '2010 - III', '2011 - I', ..., '2012 - I',
#                           '2012 - II', '2012 - III', '2013 - I']

# %%
df.Modulo.astype("category")
# Out:
# 0          Mod - V
# 1          Mod - V
# 2         Mod - VI
# 3         Mod - VI
# 4         Mod - VI
#            ...
# 38409      Mod - I
# 38410    Mod - III
# 38411      Mod - I
# 38412      Mod - V
# 38413     Mod - II
# Name: Modulo, Length: 38414, dtype: category
# Categories (6, object): ['Mod - I', 'Mod - II', 'Mod - III', 'Mod - IV', 'Mod - V', 'Mod - VI']

# %%
df.Turno.astype("category")
# Out:
# 0        Mañana
# 1        Mañana
# 2         Tarde
# 3         Tarde
# 4         Tarde
#           ...
# 38409     Noche
# 38410     Noche
# 38411     Noche
# 38412     Noche
# 38413     Noche
# Name: Turno, Length: 38414, dtype: category
# Categories (3, object): ['Mañana', 'Noche', 'Tarde']

# %%
df.Seccion.astype("category")
# Out:
# 0        A
# 1        A
# 2        A
# 3        A
# 4        A
#         ..
# 38409    B
# 38410    A
# 38411    A
# 38412    A
# 38413    A
# Name: Seccion, Length: 38414, dtype: category
# Categories (5, object): ['A', 'B', 'C', 'D', 'E']

# %%
df.IdDocente.astype("category")
# Out:
# 0        26
# 1        37
# 2        56
# 3        56
# 4        56
#          ..
# 38409    27
# 38410    46
# 38411    20
# 38412    52
# 38413    18
# Name: IdDocente, Length: 38414, dtype: category
# Categories (46, int64): [1, 2, 3, 8, ..., 123, 124, 125, 126]

# %%
df.Asistencia.astype("category")
# Out:
# 0        Puntual
# 1        Puntual
# 2        Puntual
# 3        Puntual
# 4        Puntual
#           ...
# 38409    Puntual
# 38410    Puntual
# 38411      Falto
# 38412    Puntual
# 38413    Puntual
# Name: Asistencia, Length: 38414, dtype: category
# Categories (4, object): ['Falto', 'Puntual', 'Reemplazo', 'Tarde']

# %% [markdown]
# # Función que convierte valores categóricos a numéricos

# %%
def Categ_Numerico(datos):
    # Conversión de un tipo de datos al tipo categorico
    datos = datos.astype("category")
    # Obtención del código de la categoría
    return datos.astype("category").cat.codes

# %%
df['Semestre'] = Categ_Numerico(df['Semestre'])
df['Modulo'] = Categ_Numerico(df['Modulo'])
df['Turno'] = Categ_Numerico(df['Turno'])
df['Seccion'] = Categ_Numerico(df['Seccion'])
df['IdDocente'] = Categ_Numerico(df['IdDocente'])
df['Asistencia'] = Categ_Numerico(df['Asistencia'])
df.head()
# Out:
#    Semestre  Modulo  Turno  Seccion  IdDocente  Asistencia
# 0         0       4      0        0          9           1
# 1         0       4      0        0         13           1
# 2         0       5      2        0         27           1
# 3         0       5      2        0         27           1
# 4         0       5      2        0         27           1

# %% [markdown]
# # Grabación de conversión de datos

# %%
df.to_csv("asistencia_doc.csv", sep=',',header=True, index=False)

# %% [markdown]
# # Histograma

# %% [markdown]
# *   El histograma 1 muestra el nro de Asistencias vs Semestre
# *   El histograma 2 muestra el nro de Asistencias vs Modulo
# *   El histograma 3 muestra el nro de Asistencias vs Turno
# *   El histograma 4 muestra el nro de Asistencias vs Seccion
# *   El histograma 5 muestra el nro de Asistencias vs IdDocente
# *   El histograma 6 muestra el nro de Asistencias vs categorias de asistencia

# %%
df.hist(figsize=(12, 9))
plt.show()

# %% [markdown]
# semestre = ['2010 - I', '2010 - II', '2010 - III', '2011 - I', ..., '2012 - I','2012 - II', '2012 - III', '2013 - I']
#
# turno = ['Mañana', 'Noche', 'Tarde']
#
# modulo = ['Mod - I', 'Mod - II', 'Mod - III', 'Mod - IV', 'Mod - V', 'Mod - VI']
#
# seccion = ['A', 'B', 'C', 'D', 'E']
#
# IdDocente = [1, 2, 3, 8, ..., 123, 124, 125, 126]
#
# Categoria Asistencia = ['Falto', 'Puntual', 'Reemplazo', 'Tarde']

# %% [markdown]
# INTERPRETACION:
#   - En el histograma 1 se observa que en el semestre 2013-ll el nro de asistencias fueron mayores, con una tendencia creciente
#   - En el histograma 2 se observa que la mayor cantidad de asistencias corresponden al primer modulo luego por el modulo 2, lo cual indica que hay menor numero de docentes para dichos modulos.
#   - En el histograma 3 se observa el turno de la mañana tiene mayor numero de asistencias, esto quiere decir que hay mayor nro de docentes
#   - En el histograma 4 se observa que el turno de el grupo de la seccion A tiene mayor nro de asistencia de docentes
#   - En el histograma 5 se observa que el docente con codigo 1, 10,20,30 son puntuales, y estan presentes en diferentes cursos y turnos
#   - En el histograma 6 se observa que La mayoria de docentes son puntuales, y alguno de ellos llegan tarde algunas veces, de igual manera respecto a las faltas y reemplazos

# %% [markdown]
# # Filtros

# %%
T1 = df[df.Turno == 0]
T2 = df[df.Turno == 1]
T3 = df[df.Turno == 2]

# %%
M1 = df[df.Modulo == 0]
M2 = df[df.Modulo == 1]
M3 = df[df.Modulo == 2]
M4 = df[df.Modulo == 3]
M5 = df[df.Modulo == 4]
M6 = df[df.Modulo == 0]

# %%
S1 = df[df.Semestre == 0]
S2 = df[df.Semestre == 1]
S3 = df[df.Semestre == 2]
S4 = df[df.Semestre == 3]
S5 = df[df.Semestre == 4]
S6 = df[df.Semestre == 5]

# %% [markdown]
# # Distribución

# %%
# cantidad de asistencias por semestre
df.groupby('Semestre').size()
# Out:
# Semestre
# 0     682
# 1    2589
# 2    3159
# 3    4377
# 4    4009
# 5    4655
# 6    4794
# 7    4825
# 8    4346
# 9    4978
# dtype: int64

# %%
# cantidad de asistencias por Modulo
df.groupby('Modulo').size()
# Out:
# Modulo
# 0    12178
# 1     8461
# 2     6458
# 3     4882
# 4     4081
# 5     2354
# dtype: int64

# %%
# cantidad de asistencias por turno
df.groupby('Turno').size()
# Out:
# Turno
# 0    18746
# 1     9682
# 2     9986
# dtype: int64

# %%
# cantidad de asistencias por seccion
df.groupby('Seccion').size()
# Out:
# Seccion
# 0    25093
# 1     3500
# 2     8135
# 3     1473
# 4      213
# dtype: int64

# %%
# cantidad de asistencia por docente
df.groupby('IdDocente').size()
# Out:
# IdDocente
# 0       54
# 1     1026
# 2     1838
# 3     2044
# 4     1181
# 5      614
# 6      937
# 7     1084
# 8     1081
# 9     1827
# 10    1294
# 11    1495
# 12     627
# 13    1209
# 14     322
# 15    1196
# 16     226
# 17     457
# 18    1276
# 19    1754
# 20     204
# 21    2007
# 22     740
# 23    1239
# 24     250
# 25    2070
# 26    1706
# 27    1887
# 28    2006
# 29     830
# 30     384
# 31    1258
# 32     211
# 33    1103
# 34     168
# 35      77
# 36     175
# 37     127
# 38      23
# 39      21
# 40      85
# 41      21
# 42     107
# 43      66
# 44      36
# 45      71
# dtype: int64

# %%
# cantidad de asistencias por tipo de asistencia ('Falto', 'Puntual', 'Reemplazo', 'Tarde')
df.groupby('Asistencia').size()
# Out:
# Asistencia
# 0     1015
# 1    34618
# 2      826
# 3     1955
# dtype: int64

# %% [markdown]
# # Diagrama de pie

# %%
plt.pie(df.groupby('Modulo').size(), autopct="%0.1f %%", labels=['I','II','III','IV','V','VI'])
plt.show()

# %% [markdown]
#   - El diagrama de pastel muestra que más del 50% de las asistencias corresponden al modulo 1 y 2, esto es debido a que en dichos modulos hay mayor cantidad de alumnos, por lo cual se necesitan más docentes

# %%
plt.pie(df.groupby('Turno').size(), autopct="%0.1f %%", labels=['M','N','T'])
plt.show()

# %% [markdown]
#   - El diagrama muestra la mayor cantidad de asistencias corresponden al turno de la mañana, por que es el turno con mayor demanda

# %%
plt.pie(df.groupby('Asistencia').size(), autopct="%0.1f %%", labels=['Falto', 'Puntual', 'Reemplazo', 'Tarde'])
plt.show()

# %% [markdown]
#   - EL diagrama muestra que la mayor cantidad de asistencias de los docentes esta reoresentado por la puntualidad, lo cual indica que los docentes cumplen con su responsabilidad de asistir al dictado de clases, y los pqueños porcentajes indican que suceden raras veces por diversas razones

# %% [markdown]
# #Estadisticos descriptivos

# %%
df.describe()
# Out:
#            Semestre        Modulo         Turno       Seccion     IdDocente  \
# count  38414.000000  38414.000000  38414.000000  38414.000000  38414.000000
# mean       5.296454      1.669105      0.771958      0.651872     17.054173
# std        2.540393      1.575585      0.834249      0.973198     10.211496
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.000000      0.000000      0.000000      8.000000
# 50%        5.000000      1.000000      1.000000      0.000000     18.000000
# 75%        7.000000      3.000000      2.000000      2.000000     26.000000
# max        9.000000      5.000000      2.000000      4.000000     45.000000
#
#          Asistencia
# count  38414.000000
# mean       1.096866
# std        0.492057
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000

# %% [markdown]
# #Diagrama de caja

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
plt.boxplot([T1.Asistencia, T2.Asistencia, T3.Asistencia], 
            labels=['Mañana','Noche','Tarde'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
plt.boxplot([M1.Porcentaje_Abandono, M2.Porcentaje_Abandono, M3.Porcentaje_Abandono, 
             M4.Porcentaje_Abandono, M5.Porcentaje_Abandono, M6.Porcentaje_Abandono], 
            labels=['1','2','3','4','5','6'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
plt.boxplot([S1.Porcentaje_Abandono, S2.Porcentaje_Abandono, S3.Porcentaje_Abandono, 
             S4.Porcentaje_Abandono, S5.Porcentaje_Abandono, S6.Porcentaje_Abandono], 
            labels=['A','B','C','D','E','F'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# # Correlación lineal
# Gráficos Cuantil-Cuantil (Q-Q plots)
#
# Un gráfico Cuantil-Cuantil permite observar cuan cerca está la
# distribución de un conjunto de datos a alguna distribución ideal
# ó comparar la distribución de dos conjuntos de datos.
#
# Si la linea es trazada como diagonal, existe alta approximación de los datos a la distribución ideal.
#
# **¿Por qué es importante conocer las distribuciones?**
#
# Las distribuciones de probabilidad teóricas son útiles en la inferencia estadística porque sus propiedades y características son conocidas. Si la distribución real de un conjunto de datos dado es razonablemente cercana a la de una distribución de probabilidad teórica, muchos de los cálculos se pueden realizar en los datos reales utilizando hipótesis extraídas de la distribución teórica.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import statistics
import pylab
import scipy.stats as stats

stats.probplot(df['Semestre'],dist=stats.poisson(statistics.median(df['Semestre'])), plot=pylab)
pylab.show()

# %%
import statistics
import pylab
import scipy.stats as stats

stats.probplot(df['Asistencia'],dist=stats.expon(statistics.median(df['Asistencia'])), plot=pylab)
pylab.show()

# %%
import statistics
import pylab
import scipy.stats as stats

stats.probplot(df['Porcentaje_Abandono'],dist=stats.uniform(min(df['Porcentaje_Abandono']),max(df['Porcentaje_Abandono']) ), plot=pylab)
pylab.show()

# %%
import pylab
import scipy.stats as stats

stats.probplot(df['Porcentaje_Abandono'],dist=stats.norm, plot=pylab)
pylab.show()

# %% [markdown]
# # Correlación Pearson
#
# La correlación es una medida de la relación (covariación) lineal entre dos variables cuantitativas contínuas (x, y). La manera más sencilla de saber si dos variables están correlacionadas es determinar si co-varían (varían conjuntamente)
#
# La correlación es un tipo de asociación entre dos variables numéricas, específicamente evalúa la tendencia (creciente o decreciente) en los datos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El valor del índice de correlación varía en el intervalo [-1,1]
#
# Si este coeficiente es igual a 1 o -1 (o cercano a estos valores) significa que una variable es fruto de una transformación lineal de la otra. Teniendo una relación directa al tratarse de 1 (cuando una variable aumenta, la otra también), mientras que existirá una relación inversa al tratarse de -1 (cuando una variable aumenta la otra disminuye).
#
# Mientras que, Si r = 0 (o cercano a este valor) no existe relación lineal, aunque puede existir algún otro tipo de relación no lineal.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Matriz de correlación

# %%
df_pearson = df.corr(method='pearson')
df_pearson
# Out:
#             Semestre    Modulo     Turno   Seccion  IdDocente  Asistencia
# Semestre    1.000000 -0.054834  0.035585 -0.009714   0.148898   -0.092240
# Modulo     -0.054834  1.000000  0.024705 -0.236483  -0.037195   -0.032630
# Turno       0.035585  0.024705  1.000000 -0.415704   0.039765   -0.058500
# Seccion    -0.009714 -0.236483 -0.415704  1.000000  -0.077994   -0.017103
# IdDocente   0.148898 -0.037195  0.039765 -0.077994   1.000000   -0.015453
# Asistencia -0.092240 -0.032630 -0.058500 -0.017103  -0.015453    1.000000

# %% [markdown]
# # Matriz de correlacion en mapa de colores

# %%
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,8))
sns.heatmap(df_pearson,ax=ax)

# %% [markdown]
# * Segun la matriz de correlacion se observa que las caracteristicas que influyen en el target 'Asistencia' son el modulo, la seccion y el docente
